# %%
# !pip install app_store_scraper
# Out:
# Requirement already satisfied: app_store_scraper in /usr/local/lib/python3.10/dist-packages (0.3.5)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.10/dist-packages (from app_store_scraper) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->app_store_scraper) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->app_store_scraper) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->app_store_scraper) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->app_store_scraper) (2023.7.22)

# %%
import pandas as pd
import numpy as np
import json

from app_store_scraper import AppStore
slack = AppStore(country='us', app_name='meesho-online-shopping', app_id = '1457958492')

slack.review(how_many=2000)

# %%
slack.reviews
# Out:
# [{'date': datetime.datetime(2023, 1, 13, 11, 10, 28),
#   'review': "Meesho is a really very nice app from which we are getting our favourite things at least price and nice job its doing the fastest delivery and nice items usesable appreciate work it's doing great",
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Osm app',
#   'userName': 'Patel priya'},
#  {'date': datetime.datetime(2023, 4, 26, 12, 13, 30),
#   'review': 'They only offer cash on delivery payment method. When your items arrive, they will ask for money before handling over the item to the customer. They will not let the customer check their order before making payment. Sometimes, they will give you less quantity than ordered (like give one blouse instead of 4 in the order) and take full money. On other times, they will give you complete garbage delivery and take full money. Once customer opens their packet they realize that they have been duped. It had happened with us. Police and law enforcement should act on this fraud company',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Meesho is a scam and fraud. Don’t use it',
#   'userName': 'indiagenius'},
#  {'date': datetime.datetime(2023, 7, 16, 8, 40, 23),
#   'review': 'This very helpful app I buy many things from in less price and quality and it has the same features and functionality that you would use for your business model in the same price as a website and website that I would like you can also check it for free if you’re looking to make a business website and I would love your feedback and feedback thank',
#   'rating': 4,
#   'isEdited': False,
#   'title': 'T',
#   'userName': 'Urmaan gill'},
#  {'date': datetime.datetime(2023, 7, 8, 10, 3, 39),
#   'review': 'This is the worst shopping app . When u call call customer care they respond please call after 2 hours we don’t have a infomercial about your queries 🤷🏻\u200d♀️ They don’t provide proper information about exchange . And if you order something from discount they initially place the order then cancel the order . And sometimes scam happen they send you the wrong product .  So that’s why i switch to other apps and i deleted this app 👎🏻👎🏻👎🏻\nThey need many improvements',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Worst shopping app',
#   'userName': 'rose khurana'},
#  {'date': datetime.datetime(2023, 5, 14, 6, 0, 31),
#   'review': 'I didn’t receive my order but says delivered. There is no email or customer service option to call them. When I tried to contact them from call me back option it is getting “something went wrong please try again later”. I don’t have any option to change my old phone number. I feel very bad about this horrible customer service.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Bad customer service',
#   'userName': 'Manikya 1'},
#  {'date': datetime.datetime(2021, 12, 18, 13, 45, 22),
#   'review': 'This is a worst app I have experienced…I ordered a bunch of stuff , and now suddenly my app says verification failed …Emailed them , No reply…Call them , they cannot verify my contact number as I am calling from USA…I paid for most of my orders, now I don’t even know the status of my orders…Would not recommend this app for any…Improve your customer service and app services before taking money from people',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Re: Verification failed',
#   'userName': 'Sushma Gampa'},
#  {'date': datetime.datetime(2021, 5, 4, 22, 48, 16),
#   'developerResponse': {'id': 22703366,
#    'body': "Hello Entrepreneur, We’re sorry to know that you had an unsatisfactory experience with our service. We understand your disappointment. We’ll connect with you over a call at the earliest. Also, you can reach out to us on (080)-61799600 between 10:00 AM to 7:00 PM. We'll surely have this sorted out on priority.",
#    'modified': '2021-05-09T13:17:47Z'},
#   'review': 'Meesho is very good platform for housewife to earn amount without investment.\n\nOnly thing that facing issue is with shipping vendors.\n\n1) Shipping journey will be very long\n2) Most of the customer are ought to wait for even more than 1 or 2 weeks to get single order\n3) Also Ecomm Logistics - trying only 1 time while delivering to customer- if undelivered then they will attempt for return to seller which cause customer dissatisfaction and not interested in second order \n\nPlease advice shipping logistics to ship fast delivery and try to attempt minimum 3 times to customer as other vendors do',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Must concentrate on Shipping service',
#   'userName': 'Akhathu123'},
#  {'date': datetime.datetime(2023, 7, 9, 4, 11, 54),
#   'review': 'Instagram user thewinsomesmile posted a reel in her acc with multiple short kurtis and titled “Meesho finds”. So I really wanted to purchase them as well and downloaded it. After weeks of looking I still couldn’t find it. Meshoo doesn’t even let me delete my acc now. Of course the user just smiles in her videos instead of giving links or sources. But it’s disappointing that Meesho allows creators to deceive their followers.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Mislead into Meesho',
#   'userName': 'nicetobealive'},
#  {'date': datetime.datetime(2021, 4, 20, 2, 1, 4),
#   'developerResponse': {'id': 22549334,
#    'body': "Hello Entrepreneur, We’re sorry to know that you had an unsatisfactory experience with our service. We understand your disappointment. We’ll connect with you over a call at the earliest. Also, you can reach out to us on (080)-61799600 between 10:00 AM to 7:00 PM. We'll surely have this sorted out on priority.",
#    'modified': '2021-04-30T08:24:59Z'},
#   'review': 'I couldn’t even create an account. I was blocked on the sign up page itself as I was using the app from out of India. It didn’t even allow me as guest user to explore the items. It would be helpful if we can at least use the app and ship to an Indian address. I used the other shopping apps and bought items. I am deleting the app now.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Annoying sign up',
#   'userName': 'suvi190'},
#  {'date': datetime.datetime(2022, 4, 21, 0, 20, 14),
#   'review': 'Meesho is a really very nice app from which we are getting our favourite things at least price and nice job its doing the fastest delivery and nice items usesable appreciate work it’s doing great',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Superb app meesho',
#   'userName': 'sultan bin ahmed'},
#  {'date': datetime.datetime(2022, 4, 26, 12, 22, 55),
#   'review': 'Hello massho team I ordered from your place on 8th April and today it is 26th April. Till now my order is not traced and the tracking details of my order have been removed from the order list in the court so application which is absolutely wrong. I have never seen such experience in my And I was very surprised to see that it has a rating of 4.5 which should not be at all.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Very bad',
#   'userName': 'marksharma'},
#  {'date': datetime.datetime(2023, 3, 10, 16, 32, 7),
#   'review': 'Quality product, recommended for all',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Good quality',
#   'userName': 'nazaraamir'},
#  {'date': datetime.datetime(2023, 6, 21, 14, 37, 53),
#   'review': 'Very good online platform for shopping. Excellent service and 100% customer friendly.',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Review',
#   'userName': 'Padmomanani'},
#  {'date': datetime.datetime(2021, 2, 25, 15, 18, 45),
#   'developerResponse': {'id': 21425856,
#    'body': 'Hello, Thank you for showing interest in Meesho. We would like to inform you that in Meesho reselling can be done in India and Indonesia. However, the app can be used worldwide by using an Indian number. We are sorry to inform you that the overseas shipping of the products is currently unavailable.',
#    'modified': '2021-03-03T13:42:36Z'},
#   'review': 'Hi.. Meesho is reselling app and works only with Indian phno and in India only. I get that. But if I have an Indian phno and ship to Indian address, why cant I access it?  that’s a complete flaw here .. pls add this feature. This app has to work anywhere but ship to Indian address is great feature to Indians who live outside India.',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Why can’t ppl access not from India',
#   'userName': 'jdbdiva'},
#  {'date': datetime.datetime(2023, 3, 21, 3, 37, 47),
#   'review': 'Their system and customer service is the worst. I didn’t get the refund even after returning it. Contacted the customer care multiple times but none of the customer care executives have provided the solution . They just kept me on hold and never came back. Worst experience ever.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Worst customer service',
#   'userName': 'Divyadatla'},
#  {'date': datetime.datetime(2023, 4, 11, 19, 27, 43),
#   'review': 'cheaper then all other shopping apps',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Excellent',
#   'userName': 'nilo shaikh'},
#  {'date': datetime.datetime(2023, 3, 12, 5, 13, 38),
#   'review': 'Account login problem',
#   'rating': 4,
#   'isEdited': False,
#   'title': 'Account my delete but login issue',
#   'userName': 'Deepakvemra'},
#  {'date': datetime.datetime(2021, 7, 28, 8, 38, 50),
#   'developerResponse': {'id': 24336861,
#    'body': 'Hi, we are truly sorry for the unpleasant experience you’ve been through. Please visit the Account or Help section of Meesho app to initiate a call. You can reach out to us any day between 10:00 AM to 7:00 PM. We will get this sorted at the earliest. Thanks! Meesho',
#    'modified': '2021-08-05T13:50:45Z'},
#   'review': 'Meesho need improvement. Still i am not able to share Photos and Description directly to Facebook page or Facebook Marketplace or Instagram. Please resolve this issue asap.',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'Good App for resellers.',
#   'userName': 'Ripesh21'},
#  {'date': datetime.datetime(2022, 1, 24, 14, 55, 54),
#   'review': 'I always get User Verification Failed pop up when I open the app. I can’t close the pop up or login to the app. There is a contact us button in the pop up, that takes me to an email and I never got response from the app team.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'User verification failed',
#   'userName': 'Anonymous User Zyu'},
#  {'date': datetime.datetime(2021, 12, 9, 9, 13, 36),
#   'review': 'Received product with holes in it. When tried to return it back, nobody come to my place to pickup the product. It’s been a month since return initiated. Please don’t buy any product from this app.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Pathetic service - Don’t buy any product from this app',
#   'userName': 'mangesh_th'},
#  {'date': datetime.datetime(2021, 10, 29, 6, 54, 40),
#   'review': 'Prices are very reasonable. Updates are very clear regarding dispatch and delivery.',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Products are good',
#   'userName': 'nivybalzi'},
#  {'date': datetime.datetime(2022, 8, 8, 9, 29, 26),
#   'review': 'Ordered a product 15 days before and still haven’t received it. They don’t even display proper tracking details. Never gonna order again.',
#   'rating': 2,
#   'isEdited': False,
#   'title': 'Worst service',
#   'userName': 'hlsge'},
#  {'date': datetime.datetime(2023, 9, 6, 17, 11, 26),
#   'review': 'I spent so much time choosing stuff that I want and ordered., only to realize that they canceled 95% of my order and refunded because sellers couldn’t dispatch in time!! Cannot trust them with my time again! Never shopping here.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Can’t trust!',
#   'userName': 'GenuineBuyer'},
#  {'date': datetime.datetime(2021, 7, 22, 4, 30, 31),
#   'developerResponse': {'id': 24103775,
#    'body': 'Hi, we are truly sorry for the unpleasant experience you’ve been through. Please visit the Account or Help section of Meesho app to initiate a call. You can reach out to us any day between 10:00 AM to 7:00 PM. We will get this sorted at the earliest. Thanks! Meesho',
#    'modified': '2021-07-24T13:15:14Z'},
#   'review': "It doesn't rotate and search option doesn’t work in IPAD \na lot of drawbacks\nIf an item from fav is out of stock, you cant even remove from favorites anymore",
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Screen just fits phone but doesn’t fit to ipad',
#   'userName': 'ReddyM1'},
#  {'date': datetime.datetime(2021, 6, 17, 1, 41, 31),
#   'developerResponse': {'id': 23894399,
#    'body': 'Hello, thank you for appreciating and rating us. We are glad to learn that you are enjoying using our app and service. We are grateful for your feedback and hope that you will be associated with us for a long time.',
#    'modified': '2021-07-13T04:19:12Z'},
#   'review': 'Hi meesho , love the way you guys support the local venders, yes we wish to meesho to grow even more big.',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Meesho the master',
#   'userName': 'sudha ravi'},
#  {'date': datetime.datetime(2023, 4, 23, 6, 19, 51),
#   'review': 'When I ordered from here they send me missing product and then they don’t refund me full price even I can’t contact them they not call back or not resending my mail',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Refund issue',
#   'userName': 'Shr**a'},
#  {'date': datetime.datetime(2022, 8, 27, 17, 4, 29),
#   'review': 'This app give us so things in low price this is good app',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Meesho',
#   'userName': 'buy us FL oo hii oo Ku'},
#  {'date': datetime.datetime(2020, 6, 26, 9, 14, 51),
#   'review': 'Very fast customer service \nAnd very good app for resellers \nEspecially resellers are benificial due to easy returns and aware of frauds',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Resellers',
#   'userName': 'ramyagaraga'},
#  {'date': datetime.datetime(2023, 8, 24, 8, 20, 38),
#   'review': 'It’s so interested app and comfortable',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'It’s so interested aap and comfortable',
#   'userName': 'sameeraomer'},
#  {'date': datetime.datetime(2023, 5, 2, 16, 42, 50),
#   'review': 'I ordered some items on this site. It gets canned with out doing anything. \n\nI talked with there customer care they said you have to order it again.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Worst shopping app',
#   'userName': 'sriram kale'},
#  {'date': datetime.datetime(2022, 9, 25, 12, 53, 46),
#   'review': 'I love the app for all ur needs shop at one place',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Laila Azhar',
#   'userName': 'lailaAzhar'},
#  {'date': datetime.datetime(2021, 10, 24, 1, 26, 39),
#   'review': 'It is very good and excellent  shop to do shopping at home. Indramma',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Meesho is the best',
#   'userName': 'indramma'},
#  {'date': datetime.datetime(2023, 8, 24, 20, 30, 52),
#   'review': 'Easily return back package it’s good sarvice',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'For parsal',
#   'userName': 'paliamar'},
#  {'date': datetime.datetime(2021, 6, 7, 1, 51, 22),
#   'developerResponse': {'id': 23894251,
#    'body': 'Hello, we are sorry to learn that you had an unsatisfactory experience with our app. We do understand the inconvenience it has caused you. We will shortly connect with you over a call to understand your issue better. Please grant us some time to address your concern. Thank you for your cooperation.',
#    'modified': '2021-07-13T04:12:24Z'},
#   'review': 'No new products, Yaari has unique products',
#   'rating': 3,
#   'isEdited': False,
#   'title': 'No new products, Yaari has unique products',
#   'userName': 'Loknath'},
#  {'date': datetime.datetime(2021, 3, 10, 14, 5, 55),
#   'developerResponse': {'id': 21627245,
#    'body': "Hello Mihir, We’re sorry to know that you had an unsatisfactory experience with our service. We understand your disappointment. We’ll connect with you over a call at the earliest. Also, you can reach out to us on (080)-61799600 between 10:00 AM to 7:00 PM. We'll surely have this sorted out on priority. ",
#    'modified': '2021-03-13T11:57:31Z'},
#   'review': 'I tried so much around 1 month regarding my payment issues i do lot’s of mail with all references material....still not solved.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Customer care no response',
#   'userName': 'Mihir bhayani'},
#  {'date': datetime.datetime(2022, 8, 17, 12, 20, 28),
#   'review': 'I m a seller on meesho portal  I have lost almost 1:5 lack’s on meesho we deal in brands all my product is stolen by meesho Coustmers and I haven’t got any money fake website',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Fraud website I have ever seen',
#   'userName': 'Rishi ramnani'},
#  {'date': datetime.datetime(2023, 8, 20, 12, 46, 12),
#   'review': 'Exactly as shown in the pic …but size was tight for me so I am returning it . Thanks',
#   'rating': 4,
#   'isEdited': False,
#   'title': 'Material is good …',
#   'userName': 'shine with s'},
#  {'date': datetime.datetime(2021, 12, 5, 18, 6, 53),
#   'review': 'And we’re is this store located at?',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Nice',
#   'userName': 'teamcrew'},
#  {'date': datetime.datetime(2023, 6, 20, 2, 59, 2),
#   'review': 'Best products best experience',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'I love Meesho',
#   'userName': 'Jaya Singh Ahmed'},
#  {'date': datetime.datetime(2023, 3, 11, 14, 43, 51),
#   'review': 'Meesho is just fooling customers they shoe ₹9 sale but it disappears as soon as its time for sale \nI really find it disappointing',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Issue regarding rocket sale',
#   'userName': 'Sissuuuu'},
#  {'date': datetime.datetime(2023, 8, 22, 19, 42, 10),
#   'review': 'Very nice stuff and less costly 👌',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Awesome 👍',
#   'userName': 'vish7854'},
#  {'date': datetime.datetime(2022, 12, 5, 13, 53, 42),
#   'review': 'Very nice prudent',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Thank you mesh o I love it',
#   'userName': 'viashal'},
#  {'date': datetime.datetime(2022, 9, 29, 13, 56, 30),
#   'review': 'Worst App ! 👎🏻👎🏻👎🏻👎🏻👎🏻I ever experienced At delivery I found blank envelope',
#   'rating': 4,
#   'isEdited': False,
#   'title': 'Feedback',
#   'userName': 'brar27'},
#  {'date': datetime.datetime(2023, 7, 18, 6, 25, 50),
#   'review': 'This app is very good & fast free delivery',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Best',
#   'userName': 'Ronak khatarkar'},
#  {'date': datetime.datetime(2021, 6, 3, 16, 22, 38),
#   'developerResponse': {'id': 23894243,
#    'body': 'Hello, we are sorry to learn that you had an unsatisfactory experience with our app. We do understand the inconvenience it has caused you. We will shortly connect with you over a call to understand your issue better. Please grant us some time to address your concern. Thank you for your cooperation.',
#    'modified': '2021-07-13T04:11:59Z'},
#   'review': 'They are cheating customers 2 times i lost my money no customer care assistance nothing cheating app',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Very very bad',
#   'userName': 'johnc444'},
#  {'date': datetime.datetime(2022, 10, 10, 5, 9, 15),
#   'review': 'Very good meeshoo💖💫',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Thank you',
#   'userName': 'Hapynnyy'},
#  {'date': datetime.datetime(2020, 11, 23, 12, 4, 7),
#   'developerResponse': {'id': 19346964,
#    'body': 'Hello Entrepreneur, we would be glad to assist you, request you to get in touch with us by writing an email to help@meesho.com or by calling us on 08061799600 between 10:00 AM to 7:00 PM.\r\n',
#    'modified': '2020-11-25T13:14:07Z'},
#   'review': 'can we talk to custormer care',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'i didt not get my refun back',
#   'userName': 'aliyaamjadaga'},
#  {'date': datetime.datetime(2023, 5, 18, 7, 29, 56),
#   'review': 'Amazing you 😍😍😍',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Super delivery👍👍👍👍👌😻💪',
#   'userName': 'Naga Nagaraj (. N .P. )'},
#  {'date': datetime.datetime(2023, 2, 4, 13, 23, 35),
#   'review': 'Bad',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Bad shopping app it’s coming too late',
#   'userName': 'AjayK1987'},
#  {'date': datetime.datetime(2021, 8, 23, 2, 53, 8),
#   'developerResponse': {'id': 24817001,
#    'body': 'Hi, we are truly sorry for the unpleasant experience you’ve been through. Please visit the Account or Help section of Meesho app to initiate a call. You can reach out to us any day between 10:00 AM to 7:00 PM. We will get this sorted at the earliest. Thanks! Meesho',
#    'modified': '2021-08-31T05:10:26Z'},
#   'review': 'Fix this issue',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Orders getting cancelled',
#   'userName': 'dzevilezotepa'},
#  {'date': datetime.datetime(2020, 10, 15, 5, 24, 8),
#   'developerResponse': {'id': 18684297,
#    'body': "Hello Andreaa,\nWe’re sorry to know that you had an unsatisfactory experience with our service. We understand your disappointment. We’ll connect with you over a call at the earliest. Also, you can reach out to us on (080)-61799600 or email us to 'help@meesho.com' between 10:00 AM to 7:00 PM. We'll surely have this sorted out on priority. \r\n",
#    'modified': '2020-10-25T07:19:15Z'},
#   'review': 'Ab Meesho app bakwaas ho chuki hi, kab is se naye products ka wait kar rahe hi, magar naya kuch bhi nahi de rahe. Vahi products baar baar repeat kar rahe hi suppliers, aur vo bhi price increase kar k. Resellers ko kya bachega isme?\nReselling bekaar hoti ja rahi hi, vahi products repeat kar k.',
#   'rating': 2,
#   'isEdited': False,
#   'title': 'Repeating products',
#   'userName': 'andreaa20'},
#  {'date': datetime.datetime(2023, 5, 17, 4, 18, 56),
#   'review': 'Bhut hi Accha hai mast apps',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Meesho app bhut hi Accha hai I like you',
#   'userName': 'Meesho l'},
#  {'date': datetime.datetime(2023, 9, 25, 4, 15, 13),
#   'review': 'Trusted company',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Meesho',
#   'userName': 'Brundhavanam sailu'},
#  {'date': datetime.datetime(2022, 4, 24, 6, 40, 42),
#   'review': 'Awesome collections',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Kurti',
#   'userName': 'asri17'},
#  {'date': datetime.datetime(2022, 12, 21, 7, 7, 56),
#   'review': 'thnx meesho i love it 🥰',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'i really love it🥰🥰🥰thnkx meesho',
#   'userName': 'Anjumultani'},
#  {'date': datetime.datetime(2022, 9, 5, 7, 48, 22),
#   'review': 'Good',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Good',
#   'userName': 'BhanuCharanTej'},
#  {'date': datetime.datetime(2021, 12, 7, 8, 40, 27),
#   'review': 'Fraudsss go for COD options only....',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Frauds',
#   'userName': 'kaminigaur'},
#  {'date': datetime.datetime(2023, 7, 18, 9, 46, 13),
#   'review': '😑',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Fraud app don’t download',
#   'userName': 'divya singj'},
#  {'date': datetime.datetime(2023, 3, 13, 4, 42, 7),
#   'review': 'Meesho ghtiya app mera refund do',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Ghatiya app',
#   'userName': 'Musanna-Hosanna'},
#  {'date': datetime.datetime(2021, 7, 17, 13, 2, 11),
#   'developerResponse': {'id': 24030436,
#    'body': 'Hello, thank you for appreciating and rating us. We are glad to learn that you are enjoying using our app and service. We are grateful for your feedback and hope that you will be associated with us for a long time.\r\n',
#    'modified': '2021-07-20T12:33:36Z'},
#   'review': 'Good',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Good',
#   'userName': 'Cpalatheef'},
#  {'date': datetime.datetime(2023, 2, 4, 6, 32, 54),
#   'review': 'Ooo',
#   'rating': 5,
#   'isEdited': False,
#   'title': 'Oooo',
#   'userName': 'Adash'},
#  {'date': datetime.datetime(2023, 7, 21, 4, 47, 32),
#   'review': 'Super',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'Ramaraot',
#   'title': 'Nice'},
#  {'date': datetime.datetime(2021, 12, 10, 6, 37, 45),
#   'review': 'oosaammm👌👌👌👌👌',
#   'rating': 5,
#   'isEdited': False,
#   'userName': 'nikhilmathur',
#   'title': 'Nikhilmathur'},
#  {'date': datetime.datetime(2022, 7, 9, 16, 34, 36),
#   'review': 'Parts missing.Poor quality control department .\nK S Satyanarayana',
#   'rating': 2,
#   'isEdited': False,
#   'title': 'Last consignment',
#   'userName': 'sathyem'},
#  {'date': datetime.datetime(2023, 2, 15, 17, 1, 55),
#   'review': 'Ghatia app ekdum koi issues resolve nahi karte customer support toh bhut hu kharab hai dikhate kuch hai bhej kuch dete hain pareshan kardete hain delivery boy product pick nahi karta aur customer care wale jhoot bolte hai kuch bhi purchase karne se pahle 100 baar sochna is app se Amazon flipkart jaisa support toh ye kabhi de hi nahi skte ghatia app 😡',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Waste',
#   'userName': 'sumbul sumbul fatima'},
#  {'date': datetime.datetime(2022, 9, 29, 20, 26, 2),
#   'review': 'App is good no doubt but customer service is very bad. They failed to provide required support. Not only once but twice. Because of that i had to keep useless product which is total waste of my money.courier shadowfox is worst',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Worst customer service',
#   'userName': 'Tokirin chan'},
#  {'date': datetime.datetime(2022, 8, 8, 23, 37, 55),
#   'review': 'There is always an issue saying address unserviceable. I have received one order and when ordering the same item again on the same pin code the order gets cancelled saying address unserviceable. Customer care doesnt really have a solution to this. I dont understand how to go about this. Its very disappointing.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Address unserviceable issues',
#   'userName': 'mnssabc'},
#  {'date': datetime.datetime(2022, 2, 6, 8, 27, 14),
#   'review': 'My order I’d 94815797722 I ordered chikankari kurti amount 1000/- they send me wrong product I return the product they already received return item but after 7 days I have still not received my money.. I have already email they have not respond can check please give me my money',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Requesting to return money',
#   'userName': 'hasi karmakar'},
#  {'date': datetime.datetime(2021, 10, 8, 10, 49, 50),
#   'review': 'Just ordered few things and my account not able to use. I tried to sign up using other two numbers and still those numbers not able to use. It says User verification failed. I don’t know what that means. Poor customer service, Bad quality robot working for the app. 👎👎👎 better use Amazon or Flipkart.',
#   'rating': 1,
#   'isEdited': False,
#   'title': 'Fraud app',
#   'userName': 'ubyyyy'}]

# %%
slackdf = pd.DataFrame(np.array(slack.reviews),columns=['review'])
slackdf2 = slackdf.join(pd.DataFrame(slackdf.pop('review').tolist()))
slackdf2.head()
# Out:
#                  date                                             review  \
# 0 2023-01-13 11:10:28  Meesho is a really very nice app from which we...
# 1 2023-04-26 12:13:30  They only offer cash on delivery payment metho...
# 2 2023-07-16 08:40:23  This very helpful app I buy many things from i...
# 3 2023-07-08 10:03:39  This is the worst shopping app . When u call c...
# 4 2023-05-14 06:00:31  I didn’t receive my order but says delivered. ...
#
#    rating  isEdited                                     title      userName  \
# 0       5     False                                   Osm app   Patel priya
# 1       1     False  Meesho is a scam and fraud. Don’t use it   indiagenius
# 2       4     False                                         T   Urmaan gill
# 3       1     False                        Worst shopping app  rose khurana
# 4       1     False                      Bad customer service     Manikya 1
#
#   developerResponse
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
slackdf2.to_csv('Slack-app-reviews.csv')
